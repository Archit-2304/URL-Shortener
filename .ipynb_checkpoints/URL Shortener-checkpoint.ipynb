# %% [markdown]
# # URL Shortener
#
# ![shortener.png](attachment:shortener.png)

# %%
import random
import string

# %%
DB = {}

# %% [markdown]
# # Version-1

# %%
def getShortURL(longURL):
    """
    given a long URL, returns a short URL
    """
    l = random.randint(4,6)
    
    # generating random characters
    shortURL = ''.join([random.choice(chars) for i in range(l)])
    
      
    if shortURL is DB:
        return getShortURL(longURL)
    else:
        DB[shortURL] = longURL
        
    
    result = "cm.in/"+ shortURL
    return result

# %%
url = "https://www.codingminutes.com"

# %%
getShortURL(url)
# Out:
# 'cm.in/pudrm'

# %%
# Check Database
print(DB)
# Out:
# {'pudrm': 'https://www.codingminutes.com'}

# %%
getShortURL("ide.codingminutes.com")
# Out:
# 'cm.in/kkeo'

# %%
# Check Database
print(DB)
# Out:
# {'pudrm': 'https://www.codingminutes.com', 'kkeo': 'ide.codingminutes.com'}

# %%
def getLongURL(shortURL):
    """
    given a short URL, returns a long URL.
    """
    # https://www.cm.in.abcde -> abcde
    key = shortURL.split('/')[-1]
    
    if key in DB:
        return DB[key]
    else:
        return "Short URL doesn’t exists."

# %%
getLongURL('cm.in/pudrm')
# Out:
# 'https://www.codingminutes.com'

# %%
getLongURL('cm.in/abcde')
# Out:
# 'Short URL doesn’t exists.'

# %% [markdown]
# # Version-2

# %%
def getShortURL(longURL, myShortURL=None):
    """
    given a long URL, returns a short URL
    """
    
    if myShortURL:
        if myShortURL in DB:
            return "Short URL already exists"
        else:
            DB[myShortURL] = longURL
            res = "cm.in/"+myShortURL
            return res
    
    l = random.randint(4,6)
    
    # generating random characters
    chars = string.ascii_lowercase + string.digits
    shortURL = ''.join([random.choice(chars) for i in range(l)])
    
      
    if shortURL is DB:
        return getShortURL(longURL)
    else:
        DB[shortURL] = longURL
        
    
    result = "cm.in/"+ shortURL
    return result

# %%
DB
# Out:
# {'pudrm': 'https://www.codingminutes.com', 'kkeo': 'ide.codingminutes.com'}

# %%
getShortURL("https://archit-2304.github.io/My-Portfolio/")
# Out:
# 'cm.in/b4dctp'

# %%
DB
# Out:
# {'pudrm': 'https://www.codingminutes.com',
#  'kkeo': 'ide.codingminutes.com',
#  'ptxwn': 'https://archit-2304.github.io/My-Portfolio/',
#  'b4dctp': 'https://archit-2304.github.io/My-Portfolio/'}

# %%
getLongURL("cm.in/b4dctp")
# Out:
# 'https://archit-2304.github.io/My-Portfolio/'

# %%
getShortURL("https://github.com/Archit-2304")
# Out:
# 'cm.in/xtw2o'

# %%
DB
# Out:
# {'pudrm': 'https://www.codingminutes.com',
#  'kkeo': 'ide.codingminutes.com',
#  'ptxwn': 'https://archit-2304.github.io/My-Portfolio/',
#  'b4dctp': 'https://archit-2304.github.io/My-Portfolio/',
#  'xtw2o': 'https://github.com/Archit-2304'}

# %%
getShortURL("https://github.com/Archit-2304", "GitHub")
# Out:
# 'cm.in/GitHub'

# %%
DB
# Out:
# {'pudrm': 'https://www.codingminutes.com',
#  'kkeo': 'ide.codingminutes.com',
#  'ptxwn': 'https://archit-2304.github.io/My-Portfolio/',
#  'b4dctp': 'https://archit-2304.github.io/My-Portfolio/',
#  'xtw2o': 'https://github.com/Archit-2304',
#  'GitHub': 'https://github.com/Archit-2304'}

# %%
getShortURL("https://www.facebook.com/archit.sarkar.3", "fb")
# Out:
# 'cm.in/fb'

# %%
DB
# Out:
# {'pudrm': 'https://www.codingminutes.com',
#  'kkeo': 'ide.codingminutes.com',
#  'ptxwn': 'https://archit-2304.github.io/My-Portfolio/',
#  'b4dctp': 'https://archit-2304.github.io/My-Portfolio/',
#  'xtw2o': 'https://github.com/Archit-2304',
#  'GitHub': 'https://github.com/Archit-2304',
#  'fb': 'https://www.facebook.com/archit.sarkar.3'}

# %%
getShortURL("https://github.com/Archit-2304", "Profile")
# Out:
# 'cm.in/Profile'

# %%
DB
# Out:
# {'pudrm': 'https://www.codingminutes.com',
#  'kkeo': 'ide.codingminutes.com',
#  'ptxwn': 'https://archit-2304.github.io/My-Portfolio/',
#  'b4dctp': 'https://archit-2304.github.io/My-Portfolio/',
#  'xtw2o': 'https://github.com/Archit-2304',
#  'GitHub': 'https://github.com/Archit-2304',
#  'fb': 'https://www.facebook.com/archit.sarkar.3',
#  'Profile': 'https://github.com/Archit-2304'}

# %%
def updateLongURL(shortURL, newLongURL):
    if shortURL in DB:
        shortURL = shortURL.split("/")[-1]
        DB[shortURL] = newLongURL
        res = "cm.in/" + shortURL
        return res
    else:
        return "Short URL doesn't exists."

# %%
updateLongURL("Profile", "https://www.google.com")
# Out:
# 'cm.in/Profile'

# %%
getLongURL('cm.in/Profile')
# Out:
# 'https://www.google.com'

# %%
DB
# Out:
# {'pudrm': 'https://www.codingminutes.com',
#  'kkeo': 'ide.codingminutes.com',
#  'ptxwn': 'https://archit-2304.github.io/My-Portfolio/',
#  'b4dctp': 'https://archit-2304.github.io/My-Portfolio/',
#  'xtw2o': 'https://github.com/Archit-2304',
#  'GitHub': 'https://github.com/Archit-2304',
#  'fb': 'https://www.facebook.com/archit.sarkar.3',
#  'Profile': 'https://www.google.com'}

# %%
updateLongURL("Profile", "https://github.com/Archit-2304")
# Out:
# 'cm.in/Profile'

# %%
DB
# Out:
# {'pudrm': 'https://www.codingminutes.com',
#  'kkeo': 'ide.codingminutes.com',
#  'ptxwn': 'https://archit-2304.github.io/My-Portfolio/',
#  'b4dctp': 'https://archit-2304.github.io/My-Portfolio/',
#  'xtw2o': 'https://github.com/Archit-2304',
#  'GitHub': 'https://github.com/Archit-2304',
#  'fb': 'https://www.facebook.com/archit.sarkar.3',
#  'Profile': 'https://github.com/Archit-2304'}
